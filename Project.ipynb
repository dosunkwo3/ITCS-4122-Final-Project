# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1= pd.read_csv("crime-incidents-1.csv",low_memory=False)

# %%
df1
# Out:
#         incident_id case_number incident_datetime incident_type_primary  \
# 0          10066256  09-1220204     5/2/2009 3:57              Homicide
# 1          10066257  09-1390927    5/19/2009 9:21              Homicide
# 2          10066258  09-1380053    5/18/2009 2:15              Homicide
# 3          10066259  09-1300158    5/10/2009 3:12              Homicide
# 4          10066260  09-1321088   5/12/2009 11:25              Homicide
# ...             ...         ...               ...                   ...
# 161219    838311290  18-0760040   3/17/2018 12:55         LARCENY/THEFT
# 161220    838315373  18-0760047    3/17/2018 1:02               ASSAULT
# 161221    838315374  18-0760218    3/17/2018 5:30              BURGLARY
# 161222    838319034  18-0760323    3/17/2018 3:00               ASSAULT
# 161223    838320075  18-0760453   3/17/2018 11:00         LARCENY/THEFT
#
#                                      incident_description  clearance_type  \
# ...

# %%
df2= pd.read_csv("Crimes_-_2001_to_Present.csv")

# %%
df2
# Out:
#                ID Case Number                    Date                  Block  \
# 0        10224738    HY411648  09/05/2015 01:30:00 PM        043XX S WOOD ST
# 1        10224739    HY411615  09/04/2015 11:30:00 AM    008XX N CENTRAL AVE
# 2        11646166    JC213529  09/01/2018 12:01:00 AM  082XX S INGLESIDE AVE
# 3        10224740    HY411595  09/05/2015 12:45:00 PM      035XX W BARRY AVE
# 4        10224741    HY411610  09/05/2015 01:00:00 PM    0000X N LARAMIE AVE
# ...           ...         ...                     ...                    ...
# 7444885  12549212    JE455206  11/21/2021 07:45:00 PM        042XX W 59TH ST
# 7444886  12548169    JE453263  11/21/2021 09:30:00 PM    050XX S WOLCOTT AVE
# 7444887  12547489    JE452925  11/21/2021 07:50:00 PM  120XX S PRINCETON AVE
# 7444888  12547214    JE452859  11/21/2021 06:00:00 PM     085XX S AVALON AVE
# 7444889  12546916    JE452343  11/21/2021 09:15:00 AM        007XX E 43RD ST
#
#          IUCR   Primary Type  \
# ...

# %%
df1 = df1.rename(columns={'incident_id': 'ID', 'case_number': 'Case Number','incident_datetime': 'Date','incident_type_primary': 'Primary Type','incident_description':'Description'})

# %%
df1
# Out:
#                ID Case Number             Date   Primary Type  \
# 0        10066256  09-1220204    5/2/2009 3:57       Homicide
# 1        10066257  09-1390927   5/19/2009 9:21       Homicide
# 2        10066258  09-1380053   5/18/2009 2:15       Homicide
# 3        10066259  09-1300158   5/10/2009 3:12       Homicide
# 4        10066260  09-1321088  5/12/2009 11:25       Homicide
# ...           ...         ...              ...            ...
# 161219  838311290  18-0760040  3/17/2018 12:55  LARCENY/THEFT
# 161220  838315373  18-0760047   3/17/2018 1:02        ASSAULT
# 161221  838315374  18-0760218   3/17/2018 5:30       BURGLARY
# 161222  838319034  18-0760323   3/17/2018 3:00        ASSAULT
# 161223  838320075  18-0760453  3/17/2018 11:00  LARCENY/THEFT
#
#                                               Description  clearance_type  \
# 0       Buffalo Police are investigating this report o...             NaN
# ...

# %%
Both_DFs = pd.merge(df1,df2, how='left',left_on=['ID'],right_on=['ID'])

# %%
Both_DFs
# Out:
#                ID Case Number_x           Date_x Primary Type_x  \
# 0        10066256    09-1220204    5/2/2009 3:57       Homicide
# 1        10066257    09-1390927   5/19/2009 9:21       Homicide
# 2        10066258    09-1380053   5/18/2009 2:15       Homicide
# 3        10066259    09-1300158   5/10/2009 3:12       Homicide
# 4        10066260    09-1321088  5/12/2009 11:25       Homicide
# ...           ...           ...              ...            ...
# 161219  838311290    18-0760040  3/17/2018 12:55  LARCENY/THEFT
# 161220  838315373    18-0760047   3/17/2018 1:02        ASSAULT
# 161221  838315374    18-0760218   3/17/2018 5:30       BURGLARY
# 161222  838319034    18-0760323   3/17/2018 3:00        ASSAULT
# 161223  838320075    18-0760453  3/17/2018 11:00  LARCENY/THEFT
#
#                                             Description_x  clearance_type  \
# 0       Buffalo Police are investigating this report o...             NaN
# ...
